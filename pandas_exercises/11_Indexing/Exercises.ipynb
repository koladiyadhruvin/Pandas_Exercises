# %% [markdown]
# # Ex -

# %% [markdown]
# ### Introduction:
#
# This time you will create a data
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called

# %%
chipo = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep='\t')
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Step 4.  How many values in choice description series without NaN values?

# %%
chipo.choice_description.notnull().sum()
# Out:
# 3376

# %% [markdown]
# ### Step 5. How many observations are in the dataframe?

# %%
len(chipo.index)
# Out:
# 4622

# %% [markdown]
# ### Step 6.  Print top 1000 rows

# %%
chipo.iloc[:1000]
# Out:
#      order_id  quantity                              item_name  \
# 0           1         1           Chips and Fresh Tomato Salsa
# 1           1         1                                   Izze
# 2           1         1                       Nantucket Nectar
# 3           1         1  Chips and Tomatillo-Green Chili Salsa
# 4           2         2                           Chicken Bowl
# ..        ...       ...                                    ...
# 995       409         1                           Chicken Bowl
# 996       409         1                           Chicken Bowl
# 997       410         1                        Chicken Burrito
# 998       410         1                      Canned Soft Drink
# 999       410         1                     Chicken Soft Tacos
#
#                                     choice_description item_price
# 0                                                  NaN     $2.39
# 1                                         [Clementine]     $3.39
# ...

# %% [markdown]
# ### Step 7.  Print only first 3 series

# %%
chipo.iloc[:,:3]
# Out:
#       order_id  quantity                              item_name
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
# [4622 rows x 3 columns]

# %% [markdown]
# ### Step 8. Print only item price column

# %%
chipo.iloc[:,-1:]
# Out:
#      item_price
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
# ...         ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
#
# [4622 rows x 1 columns]

# %% [markdown]
# ### Step 9. Print the order id as index column

# %%
chipo.set_index('order_id')
# Out:
#           quantity                              item_name  \
# order_id
# 1                1           Chips and Fresh Tomato Salsa
# 1                1                                   Izze
# 1                1                       Nantucket Nectar
# 1                1  Chips and Tomatillo-Green Chili Salsa
# 2                2                           Chicken Bowl
# ...            ...                                    ...
# 1833             1                          Steak Burrito
# 1833             1                          Steak Burrito
# 1834             1                     Chicken Salad Bowl
# 1834             1                     Chicken Salad Bowl
# 1834             1                     Chicken Salad Bowl
#
#                                          choice_description item_price
# order_id
# 1                                                       NaN     $2.39
# 1                                              [Clementine]     $3.39
# ...

# %% [markdown]
# ### Step 10. How many order were ordered?

# %%
chipo.quantity.sum()
# Out:
# 4972

# %% [markdown]
# ### Step 11. Sort by the name of the item

# %%
chipo.sort_values(by='item_name',ascending=True).reset_index()
# Out:
#       index  order_id  quantity          item_name  \
# 0      3389      1360         2  6 Pack Soft Drink
# 1       341       148         1  6 Pack Soft Drink
# 2      1849       749         1  6 Pack Soft Drink
# 3      1860       754         1  6 Pack Soft Drink
# 4      2713      1076         1  6 Pack Soft Drink
# ...     ...       ...       ...                ...
# 4617   2384       948         1  Veggie Soft Tacos
# 4618    781       322         1  Veggie Soft Tacos
# 4619   2851      1132         1  Veggie Soft Tacos
# 4620   1699       688         1  Veggie Soft Tacos
# 4621   1395       567         1  Veggie Soft Tacos
#
#                                      choice_description item_price
# 0                                           [Diet Coke]    $12.98
# 1                                           [Diet Coke]     $6.49
# 2                                                [Coke]     $6.49
# 3                                           [Diet Coke]     $6.49
# ...

# %% [markdown]
# ### Step 12.  How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ### Step 13.  Set the order id and quantity as index

# %%
chipo.set_index(['order_id','quantity'],inplace=True)
chipo
# Out:
#                                                item_name  \
# order_id quantity
# 1        1                  Chips and Fresh Tomato Salsa
#          1                                          Izze
#          1                              Nantucket Nectar
#          1         Chips and Tomatillo-Green Chili Salsa
# 2        2                                  Chicken Bowl
# ...                                                  ...
# 1833     1                                 Steak Burrito
#          1                                 Steak Burrito
# 1834     1                            Chicken Salad Bowl
#          1                            Chicken Salad Bowl
#          1                            Chicken Salad Bowl
#
#                                                   choice_description  \
# order_id quantity
# 1        1                                                       NaN
#          1                                              [Clementine]
# ...

# %% [markdown]
# ### Step 14. Get the values of level of order id in dataframe

# %%
chipo.index.get_level_values(0)
# Out:
# Int64Index([   1,    1,    1,    1,    2,    3,    3,    4,    4,    5,
#             ...
#             1831, 1831, 1831, 1832, 1832, 1833, 1833, 1834, 1834, 1834],
#            dtype='int64', name='order_id', length=4622)

# %% [markdown]
# ### Step 15.  Print the proper index in dataframe

# %%
chipo.reindex()
# Out:
#                                                item_name  \
# order_id quantity
# 1        1                  Chips and Fresh Tomato Salsa
#          1                                          Izze
#          1                              Nantucket Nectar
#          1         Chips and Tomatillo-Green Chili Salsa
# 2        2                                  Chicken Bowl
# ...                                                  ...
# 1833     1                                 Steak Burrito
#          1                                 Steak Burrito
# 1834     1                            Chicken Salad Bowl
#          1                            Chicken Salad Bowl
#          1                            Chicken Salad Bowl
#
#                                                   choice_description  \
# order_id quantity
# 1        1                                                       NaN
#          1                                              [Clementine]
# ...

# %% [markdown]
# ### Step 16. Print the cross section indexing of order id

# %%
chipo.xs(1,level=1)
# Out:
#                                       item_name  \
# order_id
# 1                  Chips and Fresh Tomato Salsa
# 1                                          Izze
# 1                              Nantucket Nectar
# 1         Chips and Tomatillo-Green Chili Salsa
# 3                                  Chicken Bowl
# ...                                         ...
# 1833                              Steak Burrito
# 1833                              Steak Burrito
# 1834                         Chicken Salad Bowl
# 1834                         Chicken Salad Bowl
# 1834                         Chicken Salad Bowl
#
#                                          choice_description item_price
# order_id
# 1                                                       NaN     $2.39
# 1                                              [Clementine]     $3.39
# 1                                                   [Apple]     $3.39
# 1                                                       NaN     $2.39
# ...
